# %% [markdown]
# ![](files/Python_logo_F2998D720F_seeklogo_com.gif)
#
# #Topic covered#
# >****String****
# >>- `String Slicing`
# >>- `Formated String`
#
# >****List****
# >>- `List methods`
# >>- `List Comprehension`
#
# >****Dictionary****
# >>- `Dictionary Methods`
# >>- `Dictionary Comprehension`
#
# >****Tuple****
# >>- `Tuple Methods`
#
# >****if-else satement****
# >>- `Usage`
#
# >****Loop****
# >>- `For Loop`
# >>- `While Loop`
#
# >****Function****
# >>- `Function usage`

# %%
emp = [(1,"Smith",1,"2018","10","M",3000), \
    (2,"Rose",1,"2010","20","M",4000), \
    (3,"Williams",1,"2010","10","M",1000), \
    (4,"Jones",2,"2005","10","F",2000), \
    (5,"Brown",2,"2010","40","",10000), \
      (6,"Brown",2,"2010","50","",50000) \
  ]
empColumns = ["emp_id","name","superior_emp_id","year_joined", \
       "emp_dept_id","gender","salary"]

empDF = spark.createDataFrame(data=emp, schema = empColumns)
print(empDF.display())
print(empDF.printSchema())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dept = [("Finance",10), \
    ("Marketing",20), \
    ("Sales",30), \
    ("IT",40) \
  ]
deptColumns = ["dept_name","dept_id"]
deptDF = spark.createDataFrame(data=dept, schema = deptColumns)
deptDF.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>dept_id</th></tr></thead><tbody><tr><td>Finance</td><td>10</td></tr><tr><td>Marketing</td><td>20</td></tr><tr><td>Sales</td><td>30</td></tr><tr><td>IT</td><td>40</td></tr></tbody></table></div>

# %% [markdown]
# ####*`String`*####
# ****`String Slicing`****

# %%
b = "Hello, World!"
print(b[2:5])
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(b[-3:])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">llo
# Hello
# llo, World!
# orl
# ld!
# </div>

# %% [markdown]
# #### String Methods#####
# - `strip() method removes any whitespace from the beginning or the end`
# - `replace() method replaces a string with another string`
# - `split() method splits the string into substrings if it finds instances of the separator`
# - `upper() method returns the string in upper case`
# - `lower() method returns the string in lower case`

# %%
s = "i am learning python"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
s.split(' ')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: [&#39;i&#39;, &#39;am&#39;, &#39;learning&#39;, &#39;python&#39;]</div>

# %% [markdown]
# ####*Scenerio:*####
# `Let us suppose in  ADLS directory we have multiple files having differnt file format. We need to get only those files`
#  `which has csv file format`

# %%
file_list  = ['Agent_20220421.csv','CandidateReferrer_20220421.csv','CandidateReferrer_20220421.csv','JobField_20220421.paquet','JobField_20220421.txt']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: [&#39;Agent_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;]</div>

# %%
l = []
for i in file_list:
    if i[-3:] == 'csv':
        l.append(i)
    else:
        pass
l
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [&#39;Agent_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;]</div>

# %%
p = "python"
year = 2018
print(f"i have learned {p} in {year}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">i have learned python in 2018
# </div>

# %% [markdown]
# ####List####
# `Lists are one of 4 built-in data types in Python used to store collections of data`

# %%
file_list  = ['Agent_20220421.csv','CandidateReferrer_20220421.csv','CandidateReferrer_20220421.csv','JobField_20220421.paquet','JobField_20220421.txt']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
file_list[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: &#39;Agent_20220421.csv&#39;</div>

# %%
a = [1,2,3,4,5]
b = [2,4,8,9,10]
c = a + b
c
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [1, 2, 3, 4, 5, 2, 4, 8, 9, 10]</div>

# %%
for i in file_list:
    if i[-3:] == 'csv':
        print(i)
    else:
        pass
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Agent_20220421.csv
# CandidateReferrer_20220421.csv
# CandidateReferrer_20220421.csv
# </div>

# %%
nested = [[1,2],[2,3,4,5],['hi','bye','hello']]
nested
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: [[1, 2], [2, 3, 4, 5], [&#39;hi&#39;, &#39;bye&#39;, &#39;hello&#39;]]</div>

# %% [markdown]
# ####`List Comprehension`####
# `List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list`

# %%
get_file = []
for i in file_list:
    if i[-3:] == 'csv':
        get_file.append(i)
    else:
        pass  
get_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: [&#39;Agent_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;]</div>

# %%
get_csv = [file for file in file_list if file[-3:] == 'csv']
get_csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [&#39;Agent_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;,
#  &#39;CandidateReferrer_20220421.csv&#39;]</div>

# %%
empDF.columns
print(type(empDF.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;list&#39;&gt;
# </div>

# %%
empDF.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: [(&#39;emp_id&#39;, &#39;bigint&#39;),
#  (&#39;name&#39;, &#39;string&#39;),
#  (&#39;superior_emp_id&#39;, &#39;bigint&#39;),
#  (&#39;year_joined&#39;, &#39;string&#39;),
#  (&#39;emp_dept_id&#39;, &#39;string&#39;),
#  (&#39;gender&#39;, &#39;string&#39;),
#  (&#39;salary&#39;, &#39;bigint&#39;)]</div>

# %% [markdown]
# ####Dictionary####
# `Dictionaries are used to store data values in key:value pairs.`
# `A dictionary is a collection which is ordered*, changeable and do not allow duplicates.`
# `The values in dictionary items can be of any data type`

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "file": get_file
}
print(thisdict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;brand&#39;: &#39;Ford&#39;, &#39;model&#39;: &#39;Mustang&#39;, &#39;year&#39;: 1964, &#39;file&#39;: [&#39;Agent_20220421.csv&#39;, &#39;CandidateReferrer_20220421.csv&#39;, &#39;CandidateReferrer_20220421.csv&#39;]}
# </div>

# %%
print(thisdict["brand"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Ford
# </div>

# %%
thisdict['csv_files'] = get_csv
thisdict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: {&#39;brand&#39;: &#39;Ford&#39;,
#  &#39;model&#39;: &#39;Mustang&#39;,
#  &#39;year&#39;: 1964,
#  &#39;file&#39;: [&#39;Agent_20220421.csv&#39;,
#   &#39;CandidateReferrer_20220421.csv&#39;,
#   &#39;CandidateReferrer_20220421.csv&#39;],
#  &#39;csv_files&#39;: [&#39;Agent_20220421.csv&#39;,
#   &#39;CandidateReferrer_20220421.csv&#39;,
#   &#39;CandidateReferrer_20220421.csv&#39;]}</div>

# %%
thisdict = [{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "file": get_file
}]


dict_df = spark.createDataFrame(data = thisdict)
dict_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>brand</th><th>file</th><th>model</th><th>year</th></tr></thead><tbody><tr><td>Ford</td><td>List(Agent_20220421.csv, CandidateReferrer_20220421.csv, CandidateReferrer_20220421.csv)</td><td>Mustang</td><td>1964</td></tr></tbody></table></div>

# %% [markdown]
# ####Tuple####
# - `Tuple is one of 4 built-in data types in Python used to store collections of data`
# - `A tuple is a collection which is ordered and unchangeable.`
# >>-  `Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created`
# - `Tuples are written with round brackets.`

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(&#39;apple&#39;, &#39;banana&#39;, &#39;cherry&#39;, &#39;apple&#39;, &#39;cherry&#39;)
# </div>

# %%
thistuple[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: &#39;apple&#39;</div>

# %%
deptDF.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>dept_id</th></tr></thead><tbody><tr><td>Finance</td><td>10</td></tr><tr><td>Marketing</td><td>20</td></tr><tr><td>Sales</td><td>30</td></tr><tr><td>IT</td><td>40</td></tr></tbody></table></div>

# %%
dept_id = (10,20,30)
empDF.createOrReplaceTempView("employee")
df1 = spark.sql(f"select * from employee where emp_dept_id in{dept_id}")
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ####if-else Satatement####
# `An "if statement" is written by using the if keyword`
#
# Python supports the usual logical conditions from mathematics:
# - Equals: a == b
# - Not Equals: a != b
# - Less than: a < b
# - Less than or equal to: a <= b
# - Greater than: a > b
# - Greater than or equal to: a >= b
#
# `These conditions can be used in several ways, most commonly in "if statements" and loops.`

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">a is greater than b
# </div>

# %%
s = "I m learning python"
if "m" in s:
    print("yes")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">yes
# </div>

# %%
email = "abc@gmail.com"
if "@" in email:
    print("yes")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">yes
# </div>

# %% [markdown]
# #### For Loop####
# `A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).`

# %%
for i in get_file:
    print(i)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Agent_20220421.csv
# CandidateReferrer_20220421.csv
# CandidateReferrer_20220421.csv
# </div>

# %%
for i in range(len(get_file)):
    print(get_file[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Agent_20220421.csv
# CandidateReferrer_20220421.csv
# CandidateReferrer_20220421.csv
# </div>

# %% [markdown]
# ####While Loop####
# `With the while loop we can execute a set of statements as long as a condition is true.`

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 2
# 3
# 4
# 5
# </div>

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 2
# 3
# </div>

# %% [markdown]
# ####Functions####
# - `A function is a block of code which only runs when it is called.`
#
# - `You can pass data, known as parameters, into a function.`
#
# - `A function can return data as a result.`

# %%
def get_csv_files(file_list):
    local_list = []
    for i in file_list:
        if i[-3:] == "csv":
            local_list.append(i)
    return local_list

print(get_csv_files(file_list))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Agent_20220421.csv&#39;, &#39;CandidateReferrer_20220421.csv&#39;, &#39;CandidateReferrer_20220421.csv&#39;]
# </div>

# %% [markdown]
# ####Scenerio 3####
# `create a dataframe which has columns and their crossponding datatypes of empDF dataframe as their fields`

# %%
empDF.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
empDF.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: [(&#39;emp_id&#39;, &#39;bigint&#39;),
#  (&#39;name&#39;, &#39;string&#39;),
#  (&#39;superior_emp_id&#39;, &#39;bigint&#39;),
#  (&#39;year_joined&#39;, &#39;string&#39;),
#  (&#39;emp_dept_id&#39;, &#39;string&#39;),
#  (&#39;gender&#39;, &#39;string&#39;),
#  (&#39;salary&#39;, &#39;bigint&#39;)]</div>

# %%
from pyspark.sql.functions import trim
final = []
for c in empDF.dtypes:
    if c[1] == 'string':
        final.append({"column":c[0],
                         "datatype":c[1]})

final_df = spark.createDataFrame(data = final)    
final_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>column</th><th>datatype</th></tr></thead><tbody><tr><td>name</td><td>string</td></tr><tr><td>year_joined</td><td>string</td></tr><tr><td>emp_dept_id</td><td>string</td></tr><tr><td>gender</td><td>string</td></tr></tbody></table></div>
